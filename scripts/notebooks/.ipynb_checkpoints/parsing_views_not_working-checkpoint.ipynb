# %%
import re
import json
import os
import logging

# %%
def source_table(view_path):
    """
    This function extracts the source view/table from the `sql_table_name` parameter, or from the `extends` parameter.

    :param view_path: the path of the view file

    :type view_path: string
    
    :return: json payload of view name and the source table.
    """

    with open(view_path, 'r') as f:    
        view = json.load(f)

    view_source = {'view_name': view['view_name']}
    line_dict = {}
    
    for line in view['view']:
        line_list = list(filter(None, line.split(' ')))
        if len(line_list) > 0 and (bool(re.search('extends', line_list[0])) \
                                   or bool(re.search('sql_table_name', line_list[0]))):
            line_dict[line_list[0]] = line_list[1]
        elif len(line_list) > 0 and bool(re.search('derived_table', line_list[0])):
            view_source['view_type'] = 'derived_table'

    override_key_list = [bool(re.search('sql_table_name', x)) for x in line_dict.keys()]

    if len(override_key_list) >= 1 and sum(override_key_list) >= 1:
        view_source['source_table'] = line_dict['sql_table_name:']
        view_source['view_type'] = 'sql_table_name'
    elif len(override_key_list) == 1 and sum(override_key_list) == 0:
        view_source['source_table'] = line_dict['extends:'][1:-1]
        view_source['view_type'] = 'extension'

    if view_source['view_type'] == 'derived_table':
        derived_list = get_derived_table(view['view'])
        view_source['derived_table'] = derived_list
    
    return view_source

# %%
dir_path = '..'

# %%
for view in next(os.walk(f'{dir_path}/../views'))[2]:    
    print(f'Processing view file {view}') 
    print(f'Starting to parse view {view}...')
    
    view_path = f'{dir_path}/../views/{view}'
    result = source_table(view_path)
    result_json = json.dumps(result)


#         f = open(f'{dir_path}/../maps/view-{view_folder}-{view}', "w")
#         f.write(result_json)
#         f.close()
# Out:
# Processing view file store_ddc_login.json
# Processing view file pinata_settings_changed.json
# Processing view file finance_monthly_renewal_retention.json
# Processing view file sf__leads_and_contacts_pdt.json
# Processing view file storedb_edition.json
# Processing view file ga_user_page_view_sessions_segments.json
# Processing view file hosted_trial_pages.json
# Processing view file docker_www_roi_calculator_incomplete.json
# Processing view file metrics.json
# Processing view file finance_arr.json
# Processing view file cloud_tracks.json
# Processing view file docker_user_statuses.json
# Processing view file storedb_publisher.json
# Processing view file mta_report.json
# Processing view file store_signed_up_to_become_a_publisher.json
# Processing view file billforward_fulfilled.json
# Processing view file ucp_mapped_user_actions.json
# Processing view file docker_for_desktops_users.json
# Processing view file success_pages.json
# Processing view file sf__leads_converted.json
# Processing view file docker_for_desktop_identifies.json
# Processing view file pinata_active_users.json
# Processing view file stripe_refunds.json
# Processing view file ucp_usage.json
# Processing view file docker_active_hosts.json
# Processing view file adhoc_customer_contacts.json
# Processing view file meetup_groups.json
# Processing view file dac_discovered_installation.json
# Processing view file sf__recordtypes.json
# Processing view file billforward_mrr_movements.json
# Processing view file store_tracks_pdt.json
# Processing view file store_browse.json
# Processing view file stripe_charges.json
# Processing view file sf__contacts_to_reghub_to_license.json
# Processing view file storedb_edition_plan_addon.json
# Processing view file aws_cloudfront_edition_access_logs.json
# Processing view file personal_access_token_new_access_token_modal_user_pressed_cancel.json
# Processing view file sales_productivity.json
# Processing view file personal_access_token_kebab_edit_menu_clicked.json
# Processing view file docker_for_desktops_action_designer_service_created.json
# Processing view file finance_renewal_retention_metrics.json
# Processing view file ga_user_page_view_sessions.json
# Processing view file store_logged_in_on_beta_page.json
# Processing view file billforward_accounts.json
# Processing view file metrics_weekly_diff.json
# Processing view file snowflake_github_graphql_normalized_assignees.json
# Processing view file meetup_rsvps.json
# Processing view file tracks.json
# Processing view file finance_monthly_revenue_forecast.json
# Processing view file personal_access_token_edit_modal_user_clicked_cancel.json
# Processing view file pwd_users.json
# Processing view file storedb_repository.json
# Processing view file store_account_info_update.json
# Processing view file snow_sfbase__opportunities_history.json
# Processing view file docker_for_desktops_action_designer_application_stopped.json
# Processing view file docker_for_servers_iaas_identifies_prod.json
# Processing view file milestone.json
# Processing view file snowflake_github_logins_lookup.json
# Processing view file pingdom_status.json
# Processing view file personal_access_token_copy_access_token_modal_button_clicked_to_copy_token_and_close_modal.json
# Processing view file user_emails.json
# Processing view file store_ddc_verify_account.json
# Processing view file goal.json
# Processing view file initiative_resource_classification_ndt.json
# Processing view file billforward_subscriptions.json
# Processing view file storedb_product_draft.json
# Processing view file snowflake_github_graphql_normalized_pullrequests.json
# Processing view file pingdom_responsetime.json
# Processing view file snowflake_sfdc_github_tracked_comments.json
# Processing view file official_repos_pull_12_weeks.json
# Processing view file meetup_group_member_topics.json
# Processing view file date_dimension.json
# Processing view file storedb_store_administrator.json
# Processing view file reghub_repositories.json
# Processing view file snowflake_github_graphql_normalized_labels.json
# Processing view file github_commits.json
# Processing view file account_tam_healthcheck_20181210.json
# Processing view file highland_metrics.json
# Processing view file personal_access_token_user_toggled_token_to_active.json
# Processing view file storedb_rate_plan_draft.json
# Processing view file metrics_apilog.json
# Processing view file dac_dockerize_start.json
# Processing view file aws_cloudfront_registry_access_logs.json
# Processing view file billforward_account_repo_map.json
# Processing view file gh_job_posts.json
# Processing view file callidus_participants.json
# Processing view file hosted_trial_tracks.json
# Processing view file marketo_campaigns.json
# Processing view file dense_resources_and_dates_ndt.json
# Processing view file github_graphql_crossrefs.json
# Processing view file gh_applications_history.json
# Processing view file billforward_invoiced.json
# Processing view file ucp_tracks.json
# Processing view file personal_access_token_deletion_request_cancelled.json
# Processing view file weekly_purchased_ucp_avg_stats.json
# Processing view file store_product_subscriptions.json
# Processing view file marketing_bdr_meetings.json
# Processing view file load_history_lag.json
# Processing view file pingdom_checks.json
# Processing view file metrics_current.json
# Processing view file ucp_user_actions_flow.json
# Processing view file snowflake_github_graphql_normalized_crossreferences.json
# Processing view file total_active_node_count.json
# Processing view file docker_www_tracks.json
# Processing view file storedb_plan.json
# Processing view file marketo_lead_activity_types.json
# Processing view file sf__opportunity_revenue_movements.json
# Processing view file storedb_email_notification.json
# Processing view file dtr_mixpanel.json
# Processing view file aws_cloudflare_logs.json
# Processing view file aws_cloudflare_logs_top_ips.json
# Processing view file pinata_weekly_ranked_versions.json
# Processing view file meetup_members.json
# Processing view file dac_dockerized_app.json
# Processing view file dac_dockerized_installation.json
# Processing view file ucp_api.json
# Processing view file store_storebits_download.json
# Processing view file docker_for_servers_iaas_identifies_dev.json
# Processing view file docker_for_desktops_action_designer_application_restarted.json
# Processing view file docker_www_roi_calculator_success.json
# Processing view file docker_for_desktops_action_designer_application_created.json
# Processing view file docker_user_repo_count.json
# Processing view file stripe_transfers.json
# Processing view file docker_for_desktops_vm_info.json
# Processing view file marketo_lead_snapshot_20190403.json
# Processing view file sf__opportunity_total_revenue.json
# Processing view file personal_access_token_top_right_edit_button_clicked.json
# Processing view file highland_build_requests.json
# Processing view file snowflake_sfdc_github_tracked_issues.json
# Processing view file clari_pulse_conversion_breakdown.json
# Processing view file ucp_usage_sfdc.json
# Processing view file bizible_attribution_touchpoint.json
# Processing view file staffing_allocation.json
# Processing view file mobilize.json
# Processing view file meetup_topics.json
# Processing view file store_docker_download.json
# Processing view file ucp_licensing.json
# Processing view file github_pullrequests.json
# Processing view file docker_for_desktops_action_display_image_page.json
# Processing view file initiative_need_vs_allocation_ndt.json
# Processing view file store_signed_up_for_private_beta.json
# Processing view file sf__certification_oppty.json
# Processing view file initiative_with_staffing_measures.json
# Processing view file tech_diversity.json
# Processing view file store_users.json
# Processing view file github_graphql_pullrequests.json
# Processing view file page_views.json
# Processing view file sf__opportunity_contact_role.json
# Processing view file sf__users.json
# Processing view file bucket_resources_by_initiative_count_ndt.json
# Processing view file metrics_monthly_diff.json
# Processing view file sf__deal_registrations.json
# Processing view file sf__opportunity_field_history.json
# Processing view file finance_costs_by_dept.json
# Processing view file targets_marketing_by_quarter.json
# Processing view file marketo_lead_activity_attributes.json
# Processing view file bizible_touchpoints.json
# Processing view file ucp_user_action.json
# Processing view file orc_role.json
# Processing view file dense_initiatives_and_dates_ndt.json
# Processing view file wootric_csat.json
# Processing view file docker_www_identifies.json
# Processing view file docker_www_pages.json
# Processing view file store_ddc_purchase.json
# Processing view file sfbase__users.json
# Processing view file tables.json
# Processing view file ucp_user_action_facts.json
# Processing view file store_search_performed.json
# Processing view file ga_user_page_view_sessions_week.json
# Processing view file success_thumbs_up.json
# Processing view file store_ddc_create_account.json
# Processing view file personal_access_token_new_access_token_modal_user_pressed_create.json
# Processing view file dac_discover_start.json
# Processing view file resource_denormalized_ndt.json
# Processing view file billforward_subscription_snapshot_churn.json
# Processing view file adhoc_transposed_customer_events_ndt.json
# Processing view file dates_seen.json
# Processing view file ucp_mixpanel_sfdc.json
# Processing view file engineering_team.json
# Processing view file aggregate_metrics.json
# Processing view file billforward_products.json
# Processing view file storedb_edition_plan.json
# Processing view file os_specialization.json
# Processing view file finance_planned_headcount.json
# Processing view file ucp_user_actions_funnel.json
# Processing view file ucp_users.json
# Processing view file storedb_edition_addon.json
# Processing view file marketo_lead_activity_type_attributes.json
# Processing view file ucp_sessions_user_action_facts.json
# Processing view file metrics_counter.json
# Processing view file github_issues.json
# Processing view file personal_access_token_delete_button_via_edit_modal_clicked.json
# Processing view file vena_report.json
# Processing view file metrics_apilog_repos.json
# Processing view file github_forks.json
# Processing view file snowflake_github_graphql_normalized_milestones.json
# Processing view file snowflake_sf__accounts.json
# Processing view file pinata_heartbeats.json
# Processing view file store_create_subscription.json
# Processing view file marketing_bdr_opportunities.json
# Processing view file finance_monthly_costs.json
# Processing view file sf__products.json
# Processing view file finance_revenue_forecast.json
# Processing view file success_users.json
# Processing view file sf__opportunities_base_pdt.json
# Processing view file sf__certification_account.json
# Processing view file sf__lead_history.json
# Processing view file sfbase__case_comments.json
# Processing view file ucp_usage_pdt.json
# Processing view file finance_customers_arr_segmentation.json
# Processing view file reghub_dockeruser.json
# Processing view file ucp_sessions_user_actions.json
# Processing view file staffing_need_derived.json
# Processing view file docker_user_activities.json
# Processing view file meetup_events.json
# Processing view file docker_for_desktops_action_designer_open_editor.json
# Processing view file namely_demographics.json
# Processing view file snow_sfbase__accounts.json
# Processing view file sf__opportunities_sales.json
# Processing view file store_clicked_become_a_publihser.json
# Processing view file search_performed.json
# Processing view file hosted_trial_velocity.json
# Processing view file dac_discovered_os.json
# Processing view file docker_for_desktops_action_menu_open_enterprise_edition.json
# Processing view file sf__lead_became_suspect_date.json
# Processing view file work_area.json
# Processing view file docker_for_desktop_heartbeat.json
# Processing view file sf__opportunity_contact_role_counts.json
# Processing view file github_releases.json
# Processing view file sf__users_opportunities.json
# Processing view file metrics_daily_diff.json
# Processing view file storedb_review_stats.json
# Processing view file sfbase__accounts.json
# Processing view file billforward_subscription_activity_days.json
# Processing view file load_history_recent.json
# Processing view file snowflake_github_graphql_normalized_projects.json
# Processing view file bizible_histories.json
# Processing view file personal_access_token_user_toggled_token_to_inactive.json
# Processing view file pwd_pages.json
# Processing view file docker_for_servers_iaas_tracks_prod.json
# Processing view file weekly_report.json
# Processing view file sfbase__campaign_members.json
# Processing view file docker_for_desktops_daily_heartbeat.json
# Processing view file sf__opportunities_extended.json
# Processing view file snowflake_github_graphql_normalized_issues.json
# Processing view file sfbase__leads.json
# Processing view file store_products.json
# Processing view file helper_dates.json
# Processing view file docker_for_azure_app_tracks.json
# Processing view file wootric_ces.json
# Processing view file sf__cases.json
# Processing view file resource.json
# Processing view file billforward_subscriber_snapshot.json
# Processing view file personal_access_token_edit_modal_user_clicked_save_to_modify_description_and_or_token_status.json
# Processing view file docker_for_aws_app_tracks.json
# Processing view file sf__campaign_member_statuses.json
# Processing view file dac_discovered_app.json
# Processing view file metrics_weblog.json
# Processing view file github_graphql_issues.json
# Processing view file sfbase__cases.json
# Processing view file store_ddc_trial_login.json
# Processing view file sf__leads.json
# Processing view file specialization.json
# Processing view file ucp_session_facts.json
# Processing view file success_identifies.json
# Processing view file sfbase__events.json
# Processing view file snowflake_github_graphql_normalized_releases.json
# Processing view file ucp_identifies.json
# Processing view file sf__opportunities.json
# Processing view file store_authorizer_pull.json
# Processing view file hosted_trial_identifies.json
# Processing view file sf__opportunity_history.json
# Processing view file storedb_review.json
# Processing view file snowflake_github_normalized_trends.json
# Processing view file pingdom_probes.json
# Processing view file ucp_mixpanel.json
# Processing view file github_comments_poc.json
# Processing view file docker_for_desktops_action_desginer_application_deleted.json
# Processing view file query_history.json
# Processing view file store_identifies.json
# Processing view file sf__certifications.json
# Processing view file store_product_subscriptions_no_activity.json
# Processing view file docker_for_desktop_tracks.json
# Processing view file gh_offers.json
# Processing view file store_ddc_trial_verify_account.json
# Processing view file personal_access_token_delete_forever_button_clicked_to_confirm_deletion_request.json
# Processing view file sfbase__contacts.json
# Processing view file dac_dockerize_error.json
# Processing view file meetup_member_groups.json
# Processing view file sales_quota_summary_2017h2.json
# Processing view file store_aliases.json
# Processing view file work_status.json
# Processing view file store_subscription_created.json
# Processing view file jira_issues.json
# Processing view file docker_for_desktops_event_expired_license_detected.json
# Processing view file callidus_positions.json
# Processing view file highland_build_requests_bins.json
# Processing view file sf__acv_updates.json
# Processing view file store_submitted_product_pricing.json
# Processing view file metrics_apilog_operatingsystems.json
# Processing view file store_submitted_product_information.json
# Processing view file storedb_publisher_signup.json
# Processing view file storedb_publisher_product_repo_info.json
# Processing view file marketo_programs.json
# Processing view file storedb_publisher_policy.json
# Processing view file store_submitted_product_source.json
# Processing view file storedb_publisher_signup_funnel.json
# Processing view file docker_forums_pages.json
# Processing view file sf__opportunity_products_pdt.json
# Processing view file sfbase__campaigns.json
# Processing view file personal_access_token_initial_top_right_delete_button_clicked_to_request_deletion.json
# Processing view file snowflake_reghub_dockeruser.json
# Processing view file sf__contacts.json
# Processing view file target_release.json
# Processing view file sf__opportunity_customers.json
# Processing view file marketo_lead_scoring_factors.json
# Processing view file identifies.json
# Processing view file aws_cloudfront_get_docker_logs.json
# Processing view file sf__opportunity_dockercon_renewals.json
# Processing view file calendar.json
# Processing view file pwd_identifies.json
# Processing view file marketo_leads_segment.json
# Processing view file sf__opportunity_products.json
# Processing view file sfbase__tasks.json
# Processing view file sf__campaign_members.json
# Processing view file store_ddc_trial_signup.json
# Processing view file sf__case_comments.json
# Processing view file sf__opportunity_snap_20190429.json
# Processing view file type.json
# Processing view file website_performance_timing.json
# Processing view file finance_monthly_cash_burn.json
# Processing view file dtr_server_stats.json
# Processing view file dtr_trial_conversion_to_purchases.json
# Processing view file wootric_nps.json
# Processing view file sf__tasks.json
# Processing view file office_location.json
# Processing view file personal_access_token_new_access_token_modal_initiation_new_access_token_button_clicked.json
# Processing view file pinata_mixpanel.json
# Processing view file storedb_reviewers.json
# Processing view file store_download_license.json
# Processing view file snowflake_metrics_apilog.json
# Processing view file namely_employees.json
# Processing view file metrics_api_repo_action_counts.json
# Processing view file personal_access_token_copy_access_token_modal_button_clicked_to_copy_token_directly.json
# Processing view file store_eid1_docker_downloaded.json
# Processing view file sf__events.json
# Processing view file finance_hr_forecast.json
# Processing view file personal_access_token_copy_access_token_modal_button_clicked_to_close_modal_no_copy_functionality.json
# Processing view file sf__opportunities_history.json
# Processing view file store_pages.json
# Processing view file aws_cloudfront_store_pkg_repo_access_logs.json
# Processing view file ga_user_page_view_sessions_month.json
# Processing view file status.json
# Processing view file billforward_quarterly_subscriber_snapshot.json
# Processing view file success_thumbs_down.json
# Processing view file gh_applications_latest.json
# Processing view file metrics_searchlog.json
# Processing view file dac_tracks.json
# Processing view file ga_user_page_views.json
# Processing view file store_tracks.json
# Processing view file store_free_product_subscriptions.json
# Processing view file store_ddc_trial_create_account.json
# Processing view file sf__pipeline_ndt.json
# Processing view file snowflake_metrics_apilog_repos.json
# Processing view file marketo_lead_activities.json
# Processing view file store_submitted_product_for_review.json
# Processing view file storedb_product.json
# Processing view file docker_for_desktops_action_designer_application_started.json
# Processing view file sf__opportunity_products_extended.json
# Processing view file pwd_logged_page_visits.json
# Processing view file bizible_persons.json
# Processing view file pages.json
# Processing view file sf__accounts.json
# Processing view file staffing_need.json
# Processing view file job_config.json
# Processing view file clari_pulse_breakdown.json
# Processing view file sf__campaigns.json
# Processing view file gh_candidates.json
# Processing view file finance_cashflow.json
# Processing view file ucp_client_info.json
# Processing view file pinata_staging_active_users.json
# Processing view file gh_jobs.json
# Processing view file ucp_action_list.json
# Processing view file sf__accounts_history.json
# Processing view file store_ddc_trial_verify.json
# Processing view file sfbase__opportunities.json
# Processing view file initiative.json
# Processing view file ucp_license_requests.json
# Processing view file slack_docker_community_history.json
# Processing view file snowflake_docker_active_hosts.json
# Processing view file dac_discover_error.json
# Processing view file snowflake_github_graphql_normalized_projectcards.json
# Processing view file sf__leads_and_contacts.json
# Processing view file store_search.json
# Processing view file sf__opportunity_product_active_ids.json
# Processing view file stripe_customers.json
# Processing view file namely_headcount_historical.json
# Processing view file adhoc_transposed_customer_events.json
